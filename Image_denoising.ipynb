# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread(r"C:\Users\50510\Downloads\MicrosoftTeams-image.png")
dst = cv.fastNlMeansDenoisingColored(img,None,10,10,7,21)
plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread(r"C:\Users\50510\Downloads\MicrosoftTeams-image.png")

# Check if the image is not None
if img is not None:
    # Adjust window sizes to be odd
    h, w = img.shape[:2]
    h = h if h % 2 != 0 else h - 1
    w = w if w % 2 != 0 else w - 1

    # Perform the denoising operation
    dst = cv.fastNlMeansDenoisingColored(img, None, 6, 6, 7, 11)

    # Display the original and denoised images
    plt.subplot(121), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.subplot(122), plt.imshow(cv.cvtColor(dst, cv.COLOR_BGR2RGB))
    plt.title("Denoised Image")
    plt.show()
else:
    print("Image is None. Please check the path to the image.")

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread(r"C:\Users\50510\Downloads\MicrosoftTeams-image (1).png")

# Check if the image is not None
if img is not None:
    # Adjust window sizes to be odd
    h, w = img.shape[:2]
    h = h if h % 2 != 0 else h - 1
    w = w if w % 2 != 0 else w - 1

    # Perform the denoising operation
    dst = cv.fastNlMeansDenoisingColored(img, None, 9, 9, 9, 9)

    # Display the original and denoised images
    plt.subplot(121), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.subplot(122), plt.imshow(cv.cvtColor(dst, cv.COLOR_BGR2RGB))
    plt.title("Denoised Image")
    plt.show()
else:
    print("Image is None. Please check the path to the image.")
